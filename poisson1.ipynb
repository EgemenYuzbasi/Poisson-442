# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

v=[300,320,340,360,380,400,420,440,460]

ve=[20,20,20,20,20,20,20,20,20]
c=[0,0,0,800,911,898,880,937,924]
ce=np.sqrt(np.array(c))


plt.errorbar(v, c, xerr=ve, yerr=ce, linestyle='None', marker='o',ecolor='black')
plt.xlabel('Applied Voltage(v)')
plt.ylabel('Number of Decays Counted')
plt.plot(v, c)



plt.show()


#plt.savefig('first')
# Out:
# <img src="data:image/png;base64,..." width="639.9999886971934">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy.random import normal
import matplotlib.mlab as mlab
import scipy.stats
import pandas
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm


colnames = ['A1', 'B1','C1','D1']
data = pandas.read_excel("data.xlsx",  names=colnames)
c_10 = data.A1.tolist()
c_1 = data.B1.tolist()
b_10= data.C1.tolist()
b_1= data.D1.tolist()


print ('Mean Error=',np.sqrt( np.mean(c_10)))
print ('Mean=',np.mean(c_10))
print('Standard Deviation=',np.std(c_10))

(mu, sigma) = norm.fit(c_10)
n, bins, patches=plt.hist(c_10, 14, normed=True, alpha=0.75)
print(bins)
print(n)


bins=np.round(bins)




C = np.arange(78, 138)

f = scipy.stats.norm.pdf( bins, mu, sigma)
plt.plot(bins, f, 'r--', linewidth=2)
plt.plot(C, poisson.pmf(C,106.5), 'r-', color='blue' )
print('Gaussian=',f)
print('Poisson=',poisson.pmf(bins,106.5))

plt.legend(['Gaussian Fit','Poisson Fit'])
plt.title("Histogram of Cs for 10 Sec")

plt.xlabel("Counts per Interval")
plt.ylabel("Normalized Distribution of Counts")
plt.grid(True)
plt.show()

m_g=np.mean(f)
m_p=np.mean(poisson.pmf(bins,106.5))

print('Mean Gaussian',m_g)
print('Mean Poisson',m_p)

std_g=np.std(f)/np.sqrt(len(f))
print('sigma mean Gaussian=',std_g)
std_p=np.std(poisson.pmf(bins,106.5))/np.sqrt(len(poisson.pmf(bins,106.5)))
print('sigma mean Poisson=',std_p)

chi_1=chisquare(f,m_g)
print('chi square for Gaussian=',chi_1)

print('chi square per Dof for Gaussian=',chi_1[0]/len(f))

chi_2=chisquare(poisson.pmf(bins,106.5),m_p)
print('chi square for Poisson=',chi_2)

print('chi square per Dof for Poisson=',chi_2[0]/len(f))
# Out:
# Mean Error= 10.328444591358744
# Mean= 106.67676767676768
# Standard Deviation= 11.472257519005993
# <img src="data:image/png;base64,..." width="639.9999886971934">
# [ 79.          83.14285714  87.28571429  91.42857143  95.57142857
#   99.71428571 103.85714286 108.         112.14285714 116.28571429
#  120.42857143 124.57142857 128.71428571 132.85714286 137.        ]
# [0.00487635 0.00487635 0.00731452 0.02681992 0.01462905 0.03657262
#  0.0487635  0.0292581  0.01462905 0.0195054  0.01462905 0.01219087
#  0.00487635 0.00243817]
# Gaussian= [0.00189424 0.00413378 0.00798845 0.01367039 0.02255194 0.02935689
#  0.03384072 0.03454397 0.03122543 0.02499469 0.01771702 0.00971234
#  0.0052369  0.0025005  0.00105727]
# Poisson= [0.00090494 0.00263967 0.00635672 0.01274896 0.02381384 0.03255328
#  0.03794907 0.03795743 0.03275934 0.02452418 0.01600283 0.00779045
#  0.00379304 0.0016321  0.00062294]
# Mean Gaussian 0.016028302220784066
# Mean Poisson 0.016136585670449746
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy.random import normal
import matplotlib.mlab as mlab
import scipy.stats
from scipy.stats import chisquare
import pandas
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson


print ('Mean Error=',np.sqrt( np.mean(c_1)))
print ('Mean=',np.mean(c_1))
print('Standard Deviation=',np.std(c_1))

(mu, sigma) = norm.fit(c_1)
n, bins, patches=plt.hist(c_1, 8, normed=True, alpha=0.75)
print(bins)
print('Histogram Data=',n)

C1 = np.arange(1, 19)

f = scipy.stats.norm.pdf( bins, mu, sigma)
plt.plot(bins, f, 'r--', linewidth=2)
plt.plot(C1, poisson.pmf(C1,10.5), 'r-', color='blue' )
print('Gaussian=',f)
print('Poisson=',poisson.pmf(bins,10.5))


m_g=np.mean(f)
m_p=np.mean(poisson.pmf(bins,10.5))

std_g=np.std(f)
print('sigma mean Gaussian=',std_g)
std_p=np.std(poisson.pmf(bins,10.5))
print('sigma mean Poisson=',std_p)


print('Mean Gaussian=',m_g)
print('Mean Poisson=',m_p)



plt.legend(['Gaussian Fit','Poisson Fit'])
plt.title("Histogram of Cs for 1 Sec")

plt.xlabel("Counts per Interval")
plt.ylabel("Normalized Distribution of Counts")
plt.grid(True)
plt.show()


chi_1=chisquare(f,m_g)
print('chi square for Gaussian=',chi_1)

print('chi square per Dof for Gaussian=',chi_1[0]/len(f))

chi_2=chisquare(poisson.pmf(bins,10.5),m_p)
print('chi square for Poisson=',chi_2)

print('chi square per Dof for Poisson=',chi_2[0]/len(n))






#plt.savefig('CS1')
# Out:
# Mean Error= 3.2442645584558183
# Mean= 10.525252525252526
# Standard Deviation= 3.24533366432431
# <img src="data:image/png;base64,..." width="639.9999886971934">
# [ 2.  4.  6.  8. 10. 12. 14. 16. 18.]
# Histogram Data= [0.01010101 0.01515152 0.04545455 0.14141414 0.10606061 0.09090909
#  0.05050505 0.04040404]
# Gaussian= [0.00390098 0.01628473 0.04649945 0.09081866 0.12132842 0.11086901
#  0.06929756 0.02962687 0.00866391]
# Poisson= [0.00151795 0.01394614 0.05125205 0.10090247 0.12360553 0.10323871
#  0.06253883 0.02872878 0.01035081]
# sigma mean Gaussian= 0.04213825104317008
# sigma mean Poisson= 0.04274076519662739
# Mean Gaussian= 0.05525439864492368
# Mean Poisson= 0.055120140232166125
# chi square for Gaussian= Power_divergenceResult(statistic=0.28922022862813634, pvalue=0.9999837646059396)
# chi square per Dof for Gaussian= 0.03213558095868182
# chi square for Poisson= Power_divergenceResult(statistic=0.29827495026481743, pvalue=0.9999817000402819)
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy.random import normal
import matplotlib.mlab as mlab
import scipy.stats
from scipy.stats import chisquare
import pandas
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson


print ('Mean Error=',np.sqrt( np.mean(b_1)))
print ('Mean=',np.mean(b_1))
print('Standard Deviation=',np.std(b_1))

(mu, sigma) = norm.fit(b_1)
n, bins, patches=plt.hist(b_1, 10, normed=True, alpha=0.75)
print(bins)
print('Actual Data=',n)

bins=np.round(bins)
B = np.arange(1,14 )

m_g=np.mean(f)
m_p=np.mean(poisson.pmf(bins,6))

print('Mean Gaussian',m_g)
print('Mean Poisson',m_p)

std_g=np.std(f)/np.sqrt(len(f))
print('sigma mean Gaussian=',std_g)
std_p=np.std(poisson.pmf(bins,6))/np.sqrt(len(poisson.pmf(bins,6)))
print('sigma mean Poisson=',std_p)


f = scipy.stats.norm.pdf( bins, mu, sigma)
plt.plot(bins, f, 'r--', linewidth=2)
plt.plot(B, poisson.pmf(B,6), 'r-', color='blue' )
print('Gaussian=',f)
print('Poisson=',poisson.pmf(bins,6))

plt.legend(['Gaussian Fit','Poisson Fit'])
plt.title("Histogram of Ba for 1 Sec")

plt.xlabel("Counts per Interval")
plt.ylabel("Normalized Distribution of Counts")
plt.grid(True)
plt.show()


chi_1=chisquare(f,m_g)
print('chi square for Gaussian=',chi_1)

print('chi square per Dof for Gaussian=',chi_1[0]/len(f))

chi_2=chisquare(poisson.pmf(bins,6),m_p)
print('chi square for Poisson=',chi_2)

print('chi square per Dof for Poisson=',chi_2[0]/len(f))

#plt.savefig('ba1')
# Out:
# Mean Error= 2.4761488507989844
# Mean= 6.1313131313131315
# Standard Deviation= 2.4603788188512374
# <img src="data:image/png;base64,..." width="639.9999886971934">
# [ 1.   2.2  3.4  4.6  5.8  7.   8.2  9.4 10.6 11.8 13. ]
# Actual Data= [0.06734007 0.05050505 0.06734007 0.15993266 0.18518519 0.14309764
#  0.08417508 0.03367003 0.03367003 0.00841751]
# Mean Gaussian 0.016028302220784066
# Mean Poisson 0.0744306403756627
# sigma mean Gaussian= 0.003105158057888198
# sigma mean Poisson= 0.01721343879337977
# Gaussian= [0.01842452 0.0395969  0.07214114 0.14588047 0.16191592 0.15234872
#  0.1215192  0.08216898 0.02288782 0.0094284  0.00329252]
# Poisson= [0.01487251 0.04461754 0.08923508 0.16062314 0.16062314 0.13767698
#  0.10325773 0.06883849 0.02252896 0.01126448 0.00519899]
# chi square for Gaussian= Power_divergenceResult(statistic=4.753693737841753, pvalue=0.907012535852219)
# chi square per Dof for Gaussian= 0.4753693737841753
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy.random import normal
import matplotlib.mlab as mlab
import scipy.stats
from scipy.stats import chisquare
import pandas
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import poisson


print ('Mean Error=',np.sqrt( np.mean(b_10)))
print ('Mean=',np.mean(b_10))
print('Standard Deviation=',np.std(b_10))

(mu, sigma) = norm.fit(b_10)
n, bins, patches=plt.hist(b_10, 12, normed=True, alpha=0.75)
print(bins)
print(n)

B = np.arange(45, 80)

bins=np.round(bins)


m_g=np.mean(f)
m_p=np.mean(poisson.pmf(bins,61))

print('Mean Gaussian',m_g)
print('Mean Poisson',m_p)

std_g=np.std(f)/np.sqrt(len(f))
print('sigma mean Gaussian=',std_g)
std_p=np.std(poisson.pmf(bins,61))/np.sqrt(len(poisson.pmf(bins,61)))
print('sigma mean Poisson=',std_p)



f = scipy.stats.norm.pdf( bins, mu, sigma)
plt.plot(bins, f, 'r--', linewidth=2)
plt.plot(B, poisson.pmf(B,61), 'r-', color='blue' )
print('Gaussian=',f)
print('Poisson=',poisson.pmf(bins,61))

plt.legend(['Gaussian Fit','Poisson Fit'])
plt.title("Histogram of Ba for 10 Sec")

plt.xlabel("Counts per Interval")
plt.ylabel("Normalized Distribution of Counts")
plt.grid(True)
plt.show()

chi_1=chisquare(f,m_g)
print('chi square for Gaussian=',chi_1)

print('chi square per Dof for Gaussian=',chi_1[0]/len(f))

chi_2=chisquare(poisson.pmf(bins,61),m_p)
print('chi square for Poisson=',chi_2)

print('chi square per Dof for Poisson=',chi_2[0]/len(f))

#plt.savefig('ba10')
#root of mean poisson
# Out:
# Mean Error= 7.803780487622002
# Mean= 60.898989898989896
# Standard Deviation= 7.965195692137099
# <img src="data:image/png;base64,..." width="639.9999886971934">
# [46.   48.75 51.5  54.25 57.   59.75 62.5  65.25 68.   70.75 73.5  76.25
#  79.  ]
# [0.01836547 0.03305785 0.03673095 0.04407713 0.03673095 0.05142332
#  0.03305785 0.02571166 0.04040404 0.01469238 0.01836547 0.01101928]
# Mean Gaussian 0.07541859927027245
# Mean Poisson 0.027478392872122486
# sigma mean Gaussian= 0.017579655473660576
# sigma mean Poisson= 0.004525640278108164
# Gaussian= [0.00870875 0.01641027 0.02683291 0.03441988 0.0444306  0.04976769
#  0.04960947 0.04386829 0.03366117 0.02241301 0.01294981 0.00830257
#  0.00378701]
# Poisson= [0.00780979 0.01603591 0.02744983 0.03568861 0.0461417  0.05100959
#  0.05018686 0.04346559 0.03281009 0.02171658 0.01267342 0.0082733
#  0.00395782]
# chi square for Gaussian= Power_divergenceResult(statistic=0.44212807393968934, pvalue=0.9999998658320437)
# ...

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import scipy.odr.odrpack as odrpack
from scipy.optimize import curve_fit
import numpy as np

x=np.array([2.4761488507989844,3.2442645584558183,7.803780487622002,10.328444591358744])

y=np.array([2.4603788188512374,3.24533366432431,7.965195692137099,11.472257519005993])


def f(p, x):
    B,c=p
   
    return B*x+c


linear = odrpack.Model(f)
# mydata = odrpack.Data(x, y, wd=1./np.power(sx,2), we=1./np.power(sy,2))
mydata = odrpack.RealData(x, y)

myodr = odrpack.ODR(mydata, linear, beta0=[0.,1.])

myoutput = myodr.run()

myoutput.pprint()


x_fit = np.linspace(x[0], x[-1], 100)


y_fit = f(myoutput.beta, x_fit)

plt.plot(x_fit,y_fit, label='ODR', lw=3, color='purple')

plt.xlabel('Root of Mean')
plt.ylabel('Sigma')
plt.title('Standard Deviation vs Root of Mean')

plt.scatter(x,y)
plt.show()

plt.savefig('fit')
# Out:
# Beta: [ 1.13003535 -0.4527898 ]
# Beta Std Error: [0.05337994 0.362211  ]
# Beta Covariance: [[ 0.05429606 -0.32377609]
#  [-0.32377609  2.49997345]]
# Residual Variance: 0.05247927954542441
# Inverse Condition #: 0.23433813339946308
# Reason(s) for Halting:
#   Sum of squares convergence
# <img src="data:image/png;base64,..." width="639.9999886971934">
